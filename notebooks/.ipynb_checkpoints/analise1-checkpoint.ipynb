# %%
#setup
import markupsafe
import basedosdados as bd
# !pip install db-dtypes==1.3.0

import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: db-dtypes==1.3.0 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (1.3.0)
# WARNING: Error parsing dependencies of google-cloud-bigquery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pyarrow (<2.0de,>=1.0.0) ; (python_version >= "3.5") and extra == 'all'
#             ~~~~~^
# Requirement already satisfied: packaging>=17.0 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from db-dtypes==1.3.0) (24.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from db-dtypes==1.3.0) (2.2.3)
# Requirement already satisfied: pyarrow>=3.0.0 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from db-dtypes==1.3.0) (18.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from db-dtypes==1.3.0) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->db-dtypes==1.3.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->db-dtypes==1.3.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->db-dtypes==1.3.0) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\miche\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->db-dtypes==1.3.0) (1.16.0)

# %%
#download datasets Base dos Dados
_bd_br_bd_diretorios_brasil = bd.read_table('br_bd_diretorios_brasil', 'municipio', billing_project_id="projeto-teste-1-billing-id")
_bd_br_ibge_pib = bd.read_table('br_ibge_pib', 'municipio', billing_project_id="projeto-teste-1-billing-id")
_bd_br_ibge_populacao = bd.read_table('br_ibge_populacao', 'municipio', billing_project_id="projeto-teste-1-billing-id")
# Out:
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5570/5570 [00:01<00:00, 3768.08rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 111400/111400 [00:01<00:00, 60209.10rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 174388/174388 [00:01<00:00, 92247.47rows/s]

# %%
#selecionando colunas desejadas
municipios_dir = _bd_br_bd_diretorios_brasil[['id_municipio', 'nome', 'id_uf', 'nome_uf']]
municipios_pib = _bd_br_ibge_pib[['id_municipio', 'ano', 'pib']]
municipios_pop = _bd_br_ibge_populacao[['id_municipio', 'ano','populacao']]

municipios_pib = municipios_pib[(municipios_pib["ano"]>=2002) & (municipios_pib["ano"]<=2021)]
municipios_pop = municipios_pop[(municipios_pop["ano"]>=2002) & (municipios_pop["ano"]<=2021)]

# %%
#unindo os dados de pib, populacao, e pib_per_capita na mesma tabela
municipios_data = municipios_pib.copy()
municipios_data = municipios_data.merge(municipios_pop, on=["id_municipio", "ano"], how="outer")
municipios_data["pib_pc"] = municipios_data["pib"] / municipios_data["populacao"]

# %%
municipios_data.head(50)
# Out:
#    id_municipio   ano           pib  populacao        pib_pc
# 0       1100015  2002  1.112910e+08    27237.0   4086.022690
# 1       1100015  2003  1.432220e+08    27563.0   5196.168777
# 2       1100015  2004  1.739910e+08    29001.0   5999.482776
# 3       1100015  2005  1.671270e+08    28629.0   5837.682071
# 4       1100015  2006  1.688050e+08    29005.0   5819.858645
# 5       1100015  2007  1.913640e+08    23857.0   8021.293541
# 6       1100015  2008  2.489620e+08    24577.0  10129.877528
# 7       1100015  2009  2.569860e+08    24354.0  10552.106430
# 8       1100015  2010  2.620770e+08    24392.0  10744.383404
# 9       1100015  2011  2.805100e+08    24228.0  11577.926366
# 10      1100015  2012  3.290290e+08    24069.0  13670.239727
# 11      1100015  2013  3.413250e+08    25728.0  13266.674440
# 12      1100015  2014  3.777990e+08    25652.0  14727.857477
# 13      1100015  2015  4.213000e+08    25578.0  16471.186176
# 14      1100015  2016  4.782170e+08    25506.0  18749.196268
# 15      1100015  2017  4.853740e+08    25437.0  19081.416834
# 16      1100015  2018  4.989800e+08    23167.0  21538.395131
# 17      1100015  2019  4.957750e+08    22945.0  21607.103944
# 18      1100015  2020  5.702420e+08    22728.0  25089.845125
# 19      1100015  2021  7.344690e+08    22516.0  32619.870314
# 20      1100023  2002  4.495930e+08    78039.0   5761.132254
# 21      1100023  2003  5.396360e+08    79680.0   6772.540161
# 22      1100023  2004  6.571930e+08    86901.0   7562.548187
# 23      1100023  2005  7.490210e+08    85031.0   8808.799144
# 24      1100023  2006  7.906970e+08    86924.0   9096.417560
# 25      1100023  2007  9.052030e+08    82388.0  10987.073360
# 26      1100023  2008  1.064822e+09    84581.0  12589.375865
# 27      1100023  2009  1.133095e+09    85541.0  13246.221110
# 28      1100023  2010  1.364694e+09    90353.0  15104.025323
# 29      1100023  2011  1.651885e+09    91570.0  18039.587201
# 30      1100023  2012  1.703642e+09    92747.0  18368.701953
# 31      1100023  2013  1.799853e+09   101269.0  17772.990747
# 32      1100023  2014  1.921532e+09   102860.0  18681.042193
# 33      1100023  2015  2.037799e+09   104401.0  19518.960546
# 34      1100023  2016  2.184346e+09   105896.0  20627.275818
# 35      1100023  2017  2.287910e+09   107345.0  21313.614980
# 36      1100023  2018  2.464704e+09   106168.0  23215.130736
# 37      1100023  2019  2.579278e+09   107863.0  23912.537200
# 38      1100023  2020  2.817331e+09   109523.0  25723.647088
# 39      1100023  2021  3.209761e+09   111148.0  28878.261417
# 40      1100031  2002  3.176800e+07     7490.0   4241.388518
# 41      1100031  2003  4.098500e+07     7478.0   5480.743514
# 42      1100031  2004  4.339200e+07     7421.0   5847.190406
# 43      1100031  2005  4.913000e+07     7436.0   6607.046799
# 44      1100031  2006  4.688400e+07     7421.0   6317.746934
# 45      1100031  2007  4.916600e+07     6575.0   7477.718631
# 46      1100031  2008  6.058800e+07     6777.0   8940.239044
# 47      1100031  2009  6.977600e+07     6695.0  10422.106049
# 48      1100031  2010  6.961100e+07     6313.0  11026.611754
# 49      1100031  2011  7.721700e+07     6221.0  12412.313133

# %%
#Rio de Janeiro
#municipios_data[municipios_data["id_municipio"]=="3304557"]
