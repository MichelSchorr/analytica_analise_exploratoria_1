# %%
import markupsafe
import basedosdados as bd

# %%
# !pip install db-dtypes==1.3.0
# Out:
# ...
# WARNING: Error parsing dependencies of google-cloud-bigquery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pyarrow (<2.0de,>=1.0.0) ; (python_version >= "3.5") and extra == 'all'
#             ~~~~~^

# %%
df = bd.read_table('br_ibge_pib', 'municipio', billing_project_id="projeto-teste-1-billing-id")
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 111400/111400 [00:02<00:00, 38555.94rows/s]

# %%
df
# Out:
#        id_municipio   ano           pib  impostos_liquidos            va  \
# 0           1100346  2002  6.686900e+07          3643000.0  6.322600e+07
# 1           1101500  2002  3.970800e+07          2199000.0  3.750900e+07
# 2           1502954  2002  5.584200e+07          2219000.0  5.362300e+07
# 3           1505635  2002  5.205500e+07          1346000.0  5.070900e+07
# 4           1506401  2002  1.445600e+07           264000.0  1.419100e+07
# ...             ...   ...           ...                ...           ...
# 111395      5213087  2021  1.296632e+09         49832000.0  1.246800e+09
# 111396      5215306  2021  9.381550e+08         58282000.0  8.798740e+08
# 111397      5218391  2021  7.208600e+07          4299000.0  6.778700e+07
# 111398      5219803  2021  2.062450e+08          7951000.0  1.982930e+08
# 111399      5221577  2021  7.741800e+07          3823000.0  7.359500e+07
#
#         va_agropecuaria  va_industria  va_servicos   va_adespss
# ...
